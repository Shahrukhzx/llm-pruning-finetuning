# %%
# !pip install lm_eval
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 3.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 85.7 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 98.4 MB/s eta 0:00:00:00:01
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=1688ac98427f435b375370f5628585ee111db6bb63ce7c37f5dfa7dff44964a4
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# ...

# %%
# importing the required libraries
import torch
import torch.nn as nn
from transformers import AutoModelForCausalLM, AutoTokenizer, default_data_collator, Trainer, TrainingArguments
from collections import OrderedDict
from typing import List, Optional
import numpy as np
from tqdm.notebook import tqdm
from datasets import load_dataset
import torch
from torch.utils.data import DataLoader
from lm_eval import evaluator, tasks

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
def evaluate_hf_model(model_name, tasks, num_fewshot=0):
    """
    It calls the evaluator to evaluate a model available on Hugging Face.

    Args:
    - model_name: The model name in hugging Face.
    - tasks: Tasks to evaluate.
    - num_fewshot: Number of examples of few-shot learning

    Returns:
    - metrics.
    """
    model_args = f"pretrained={model_name},device=cuda"
    tasks = tasks

    results = evaluator.simple_evaluate(
      model="hf",
      model_args=model_args,
      tasks=tasks,
      num_fewshot=0,  # Number of few-shot smaples.
      limit=1000,  # Use all the samples in the Evaluate Dataset.
      bootstrap_iters=10
    )

    metrics = results.get('results', {})
    return metrics

# %%
# Select tasks to evaluate.
tasks = ["hellaswag", "mmlu", "boolq",'lambada','arc_easy']  # Choose relevant tasks

# %%
metrics_pruned_4l = evaluate_hf_model("Shahrukh0/short-llama-3.2-3B-final", tasks=tasks)
metrics_pruned_4l
# Out:
# config.json:   0%|          | 0.00/884 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/17.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/654M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/6.84k [00:00<?, ?B/s]
# hellaswag.py:   0%|          | 0.00/4.36k [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/2.53k [00:00<?, ?B/s]
# ...
# Map:   0%|          | 0/10042 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# mmlu_no_train.py:   0%|          | 0.00/5.86k [00:00<?, ?B/s]
# ...

# %%
metrics_pruned_5l = evaluate_hf_model("Shahrukh0/short-llama-3.2-3B-final-5l", tasks=tasks)
metrics_pruned_5l
# Out:
# config.json:   0%|          | 0.00/884 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/17.2k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/453M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# ...
# Running loglikelihood requests: 100%|██████████| 66029/66029 [39:46<00:00, 27.67it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 197.52it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 218.99it/s]
# {'arc_easy': {'alias': 'arc_easy',
#   'acc,none': 0.556,
#   'acc_stderr,none': 0.015719768163402086,
# ...

# %%
metrics_pruned_6l = evaluate_hf_model("Shahrukh0/short-llama-3.2-3B-final-6l", tasks=tasks)
metrics_pruned_6l
# Out:
# config.json:   0%|          | 0.00/884 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/252M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# ...
# Running loglikelihood requests: 100%|██████████| 66029/66029 [38:17<00:00, 28.73it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 187.98it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 206.95it/s]
# {'arc_easy': {'alias': 'arc_easy',
#   'acc,none': 0.52,
#   'acc_stderr,none': 0.01580663942303517,
# ...

# %%
metrics_pruned_7l = evaluate_hf_model("Shahrukh0/short-llama-3.2-3B-final-7l", tasks=tasks)
metrics_pruned_7l
# Out:
# config.json:   0%|          | 0.00/884 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/50.4M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# ...
# Running loglikelihood requests: 100%|██████████| 66029/66029 [36:50<00:00, 29.87it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 177.32it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 242.36it/s]
# {'arc_easy': {'alias': 'arc_easy',
#   'acc,none': 0.484,
#   'acc_stderr,none': 0.01581119837311488,
# ...

# %%
metrics_base= evaluate_hf_model("meta-llama/Llama-3.2-3B", tasks=tasks)
metrics_base
# Out:
# config.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# ...
# Running loglikelihood requests: 100%|██████████| 66029/66029 [1:27:37<00:00, 12.56it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 188.55it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 181.55it/s]
# {'arc_easy': {'alias': 'arc_easy',
#   'acc,none': 0.742,
#   'acc_stderr,none': 0.013842963108656603,
# ...

# %%
metrics_pruned_12l = evaluate_hf_model("Shahrukh0/short-llama-3.2-3B-final-12l", tasks=tasks)
metrics_pruned_12l
# Out:
# config.json:   0%|          | 0.00/884 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.01G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# ...
# Running loglikelihood requests: 100%|██████████| 66029/66029 [29:34<00:00, 37.22it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 157.81it/s]
# bootstrapping for stddev: perplexity
# 100%|██████████| 1/1 [00:00<00:00, 192.13it/s]
# {'arc_easy': {'alias': 'arc_easy',
#   'acc,none': 0.34,
#   'acc_stderr,none': 0.014987482264363935,
#   'acc_norm,none': 0.321,
#   'acc_norm_stderr,none': 0.01477082181793464},
#  'boolq': {'alias': 'boolq',
#   'acc,none': 0.644,
#   'acc_stderr,none': 0.015149042659306625},
#  'hellaswag': {'alias': 'hellaswag',
#   'acc,none': 0.297,
# ...
